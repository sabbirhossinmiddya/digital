# %% [markdown]
# # My Jupyter Notebook in IBM Watson studio

# %% [markdown]
#  Sabbir Hossain Midday

# %% [markdown]
# 100% Human

# %% [markdown]
# i interested from data science because I love gain insights from data

# %% [markdown]
# The Following code tests Guess the formula

# %%
2*(2+1)
# Out:
# 6

# %%
1+1+1
# Out:
# 3

# %% [markdown]
# |one|two|three|
# |1|2|3|

# %% [raw]
# •one
# •two
# •three
# •one
# •two
# •three
